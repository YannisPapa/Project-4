# %%
import pandas as pd
import re
from langdetect import detect,detect_langs,DetectorFactory
import emoji
from pprint import pprint
from datetime import datetime

# Ensure consistent language detection results
DetectorFactory.seed = 0

# %%
file_path = 'data/english_video_data.csv'
videos_df = pd.read_csv(file_path)
videos_df
# Out:
#                    c_channel_id   v_video_id v_date_publishedAt  \
# 0      UC295-Dw_tDNtZXFeAPAW6Aw  oGga7hZypCs         2024-09-02
# 1      UC295-Dw_tDNtZXFeAPAW6Aw  pkzIiXkRxB0         2024-08-30
# 2      UC295-Dw_tDNtZXFeAPAW6Aw  TUS8vZaHNds         2024-08-31
# 3      UC295-Dw_tDNtZXFeAPAW6Aw  rBzKTkUG3Wk         2024-08-31
# 4      UC295-Dw_tDNtZXFeAPAW6Aw  XHQP6mut8YI         2024-09-01
# ...                         ...          ...                ...
# 22511  UCf1U16LSYc8QhortB6Bg1Zw  3_hSnZsG1i0         2024-07-18
# 22512  UCf1U16LSYc8QhortB6Bg1Zw  Uev83QY04h8         2024-08-12
# 22513  UCf1U16LSYc8QhortB6Bg1Zw  s4gMPgVB0N4         2024-08-12
# 22514  UCco0YFnoXvvXL5tD6Cc7Lbw  MqZ-rzkT6Ck         2024-12-06
# 22515  UC9m5bhs8lLRh7k9EAJAo94Q  OPXQ6XBpMZY         2024-10-13
#
#       v_time_publishedAt            c_channel_title c_channel_upload_playlist  \
# 0               11:00:48            5-Minute Crafts  UU295-Dw_tDNtZXFeAPAW6Aw
# ...

# %%
five_min_vids = videos_df.loc[videos_df['c_channel_title'] == '5-Minute Crafts']
five_min_vids.sort_values('v_views',ascending=False)
# Out:
#                  c_channel_id   v_video_id v_date_publishedAt  \
# 192  UC295-Dw_tDNtZXFeAPAW6Aw  8x4PyC-rjLg         2024-11-10
# 342  UC295-Dw_tDNtZXFeAPAW6Aw  lZFq3KoJ7Xw         2024-01-26
# 427  UC295-Dw_tDNtZXFeAPAW6Aw  7Twkqyyromk         2024-06-24
# 363  UC295-Dw_tDNtZXFeAPAW6Aw  -vV9xdqn7nk         2024-06-09
# 508  UC295-Dw_tDNtZXFeAPAW6Aw  p8A1JRujgM8         2024-01-01
# ..                        ...          ...                ...
# 175  UC295-Dw_tDNtZXFeAPAW6Aw  rTlVxEXm9zc         2024-10-08
# 444  UC295-Dw_tDNtZXFeAPAW6Aw  uK5dc8DoyD0         2024-05-01
# 9    UC295-Dw_tDNtZXFeAPAW6Aw  c1hWRMWDnSI         2024-09-06
# 162  UC295-Dw_tDNtZXFeAPAW6Aw  FrZjBw3qOmk         2024-10-19
# 219  UC295-Dw_tDNtZXFeAPAW6Aw  sFBRZma9VEc         2024-03-09
#
#     v_time_publishedAt  c_channel_title c_channel_upload_playlist  \
# 192           10:00:09  5-Minute Crafts  UU295-Dw_tDNtZXFeAPAW6Aw
# 342           13:00:48  5-Minute Crafts  UU295-Dw_tDNtZXFeAPAW6Aw
# ...

# %%
videos_df.dtypes
# Out:
# c_channel_id                 object
# v_video_id                   object
# v_date_publishedAt           object
# v_time_publishedAt           object
# c_channel_title              object
# c_channel_upload_playlist    object
# c_channel_subCount            int64
# c_channel_videoCount          int64
# c_channel_viewCount           int64
# v_category_id                 int64
# v_tags                       object
# v_title                      object
# v_description                object
# v_comment_count               int64
# v_likes                       int64
# v_favorites                   int64
# v_views                       int64
# v_definition                 object
# v_duration                   object
# v_caption                      bool
# v_age_restricted             object
# v_privacy_status             object
# v_made_for_kids                bool
# dtype: object

# %%
videos_df['v_duration'] = videos_df['v_duration'].apply(lambda x: datetime.strptime(x, "%H:%M:%S").time())
videos_df['duration_seconds'] = videos_df['v_duration'].apply(lambda x: x.hour * 3600 + x.minute * 60 + x.second)

# %%
short_videos = videos_df.loc[videos_df['duration_seconds'] < 20]
short_videos
# Out:
#                    c_channel_id   v_video_id v_date_publishedAt  \
# 219    UC295-Dw_tDNtZXFeAPAW6Aw  sFBRZma9VEc         2024-03-09
# 523    UC2etEuPIfohP4P53wM0KImA  2IORbM9__gY         2024-07-31
# 625    UC2etEuPIfohP4P53wM0KImA  Lg_Iq34Xfdg         2024-08-19
# 813    UC2etEuPIfohP4P53wM0KImA  dCGLTEWMmzw         2024-11-10
# 814    UC2etEuPIfohP4P53wM0KImA  nGP95OqIWfk         2024-11-10
# ...                         ...          ...                ...
# 22505  UCMRnsnlHHtVt0WmTzoVyk-w  QCephxxMb0Q         2024-11-08
# 22506  UCMRnsnlHHtVt0WmTzoVyk-w  5-fx67uGpJs         2024-11-09
# 22512  UCf1U16LSYc8QhortB6Bg1Zw  Uev83QY04h8         2024-08-12
# 22513  UCf1U16LSYc8QhortB6Bg1Zw  s4gMPgVB0N4         2024-08-12
# 22514  UCco0YFnoXvvXL5tD6Cc7Lbw  MqZ-rzkT6Ck         2024-12-06
#
#       v_time_publishedAt            c_channel_title c_channel_upload_playlist  \
# 219             14:00:44            5-Minute Crafts  UU295-Dw_tDNtZXFeAPAW6Aw
# ...

# %%
long_videos = videos_df.loc[videos_df['duration_seconds'] > 3600]
long_videos
# Out:
#                    c_channel_id   v_video_id v_date_publishedAt  \
# 0      UC295-Dw_tDNtZXFeAPAW6Aw  oGga7hZypCs         2024-09-02
# 1      UC295-Dw_tDNtZXFeAPAW6Aw  pkzIiXkRxB0         2024-08-30
# 2      UC295-Dw_tDNtZXFeAPAW6Aw  TUS8vZaHNds         2024-08-31
# 3      UC295-Dw_tDNtZXFeAPAW6Aw  rBzKTkUG3Wk         2024-08-31
# 5      UC295-Dw_tDNtZXFeAPAW6Aw  dQZdvfmNh3g         2024-09-03
# ...                         ...          ...                ...
# 22261  UC46nOZqqyA3-YqORjILMZSg  VXpZ721Fl4c         2024-09-28
# 22262  UC46nOZqqyA3-YqORjILMZSg  wSMaP8uTaJg         2024-09-29
# 22264  UC46nOZqqyA3-YqORjILMZSg  0djuMn1w1Gs         2024-09-26
# 22267  UC46nOZqqyA3-YqORjILMZSg  P8SGNPYmcO8         2024-09-28
# 22268  UC46nOZqqyA3-YqORjILMZSg  JYKcYBFuiH0         2024-09-28
#
#       v_time_publishedAt  c_channel_title c_channel_upload_playlist  \
# 0               11:00:48  5-Minute Crafts  UU295-Dw_tDNtZXFeAPAW6Aw
# ...

# %%
subscribers_videos = videos_df.loc[(videos_df['c_channel_subCount'] > 1000000) & (videos_df['c_channel_id'] != 'UC295-Dw_tDNtZXFeAPAW6Aw')]
subscribers_videos
# Out:
#                   c_channel_id   v_video_id v_date_publishedAt  \
# 509   UC2etEuPIfohP4P53wM0KImA  dPDR18Gy_jk         2024-04-27
# 510   UC2etEuPIfohP4P53wM0KImA  F-HFUItbD9w         2024-07-31
# 511   UC2etEuPIfohP4P53wM0KImA  IjqNQiap8fQ         2024-07-27
# 512   UC2etEuPIfohP4P53wM0KImA  MsNvAxYoWac         2024-07-27
# 513   UC2etEuPIfohP4P53wM0KImA  P5CpLxih48A         2024-07-28
# ...                        ...          ...                ...
# 3348  UC0zPeFD5tCZrfjPD-unAeAw  6wqss8Mag3M         2024-01-03
# 3349  UC0zPeFD5tCZrfjPD-unAeAw  G9w9Bg35Hh4         2024-05-09
# 3350  UC0zPeFD5tCZrfjPD-unAeAw  TWnnZFZe_7I         2024-05-09
# 3351  UC0zPeFD5tCZrfjPD-unAeAw  5D2iOQOZOrU         2024-05-09
# 3352  UC0zPeFD5tCZrfjPD-unAeAw  pyM5uz2ZhkA         2024-01-31
#
#      v_time_publishedAt      c_channel_title c_channel_upload_playlist  \
# 509            15:00:28  5-Minute Crafts DIY  UU2etEuPIfohP4P53wM0KImA
# ...
